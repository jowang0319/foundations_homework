# %% [markdown]
# ## Homework Jun 13,2016
# ## Part 2
# ## Zhizhou Wang

# %%
import pandas as pd
# Out:
# /Users/zhizhou/.virtualenvs/data-analysis/lib/python3.5/site-packages/matplotlib/__init__.py:1035: UserWarning: Duplicate key in file "/Users/zhizhou/.matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /Users/zhizhou/.virtualenvs/data-analysis/lib/python3.5/site-packages/matplotlib/__init__.py:1035: UserWarning: Duplicate key in file "/Users/zhizhou/.matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
billion = pd.read_excel('Billionaires1996,2001and2014updated.xlsx')

# %%
billion.head(2)
# Out:
#    year                  name  rank    citizenship countrycode  \
# 0  2001   A Jerrold Perenchio   151  United States         USA
# 1  2014  A. Jerrold Perenchio   663  United States         USA
#
#    networthusbillion   selfmade typeofwealth gender   age   ...     \
# 0                3.0  self-made    executive   male  70.0   ...
# 1                2.6  self-made    executive   male  83.0   ...
#
#      relationshiptocompany foundingdate  gdpcurrentus         sourceofwealth  \
# 0  former chairman and CEO       1955.0  1.062180e+13                    NaN
# 1  former chairman and CEO       1955.0           NaN  television, Univision
#
#                                             notes  notes2  \
# 0  represented Marlon Brando and Elizabeth Taylor     NaN
# 1  represented Marlon Brando and Elizabeth Taylor     NaN
#
#                                          source  \
# 0  http://en.wikipedia.org/wiki/Jerry_Perenchio
# 1  http://en.wikipedia.org/wiki/Jerry_Perenchio
#
# ...

# %%
recent= billion[billion['year'] == 2014]

# %%
recent.head(2) # should do with 2014, or it would be hard to compare
# Out:
#    year                  name  rank           citizenship countrycode  \
# 1  2014  A. Jerrold Perenchio   663         United States         USA
# 5  2014    Abdulla Al Futtaim   687  United Arab Emirates         ARE
#
#    networthusbillion   selfmade typeofwealth gender   age   ...     \
# 1                2.6  self-made    executive   male  83.0   ...
# 5                2.5  inherited    inherited   male   NaN   ...
#
#      relationshiptocompany foundingdate gdpcurrentus  \
# 1  former chairman and CEO       1955.0          NaN
# 5                 relation       1930.0          NaN
#
#               sourceofwealth                                           notes  \
# 1      television, Univision  represented Marlon Brando and Elizabeth Taylor
# 5  auto dealers, investments    company split between him and cousin in 2000
#
#    notes2                                         source  \
# 1     NaN   http://en.wikipedia.org/wiki/Jerry_Perenchio
# ...

# %% [markdown]
# ### What country are most billionaires from?

# %%
billion['citizenship'].describe()
# Out:
# count              2614
# unique               73
# top       United States
# freq                903
# Name: citizenship, dtype: object

# %% [markdown]
# ### Who are the top 10 richest billionaires?

# %%
billion.sort_values('networthusbillion',ascending=False).head(10)
# Out:
#       year              name  rank    citizenship countrycode  \
# 284   2014        Bill Gates     1  United States         USA
# 348   2014  Carlos Slim Helu     2         Mexico         MEX
# 124   2014    Amancio Ortega     3          Spain         ESP
# 283   2001        Bill Gates     1  United States         USA
# 2491  2014    Warren Buffett     4  United States         USA
# 1377  2014     Larry Ellison     5  United States         USA
# 509   2014        David Koch     6  United States         USA
# 381   2014      Charles Koch     6  United States         USA
# 2185  2014   Sheldon Adelson     8  United States         USA
# 429   2014    Christy Walton     9  United States         USA
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 284                76.0  self-made       founder non-finance    male  58.0
# 348                72.0  self-made  privatized and resources    male  74.0
# ...

# %% [markdown]
# ### What's the average wealth of a billionaire? Male? Female?

# %%
billion['networthusbillion'].mean()
# Out:
# 3.5319433817903594

# %%
billion[billion['gender'] == 'male']['networthusbillion'].mean()
# Out:
# 3.5168814432989697

# %%
billion[billion['gender'] == 'female']['networthusbillion'].mean()
# Out:
# 3.8192771084337349

# %% [markdown]
# ### Who is the poorest billionaire? Who are the top 10 poorest billionaires?

# %%
billion.sort_values('networthusbillion',ascending=False).tail(10)
# Out:
#       year                         name  rank     citizenship countrycode  \
# 1048  2001                 James France   490   United States         USA
# 1660  2014                Michael Lynch  1565  United Kingdom         GBR
# 2472  2014                Wang Jianfeng  1565           China         CHN
# 107   1996  Alicia and Esther Koplowitz   405           Spain         ESP
# 1475  2014              Lin Ming-Hsiung  1565          Taiwan      Taiwan
# 1033  2001              Jacques Servier   490          France         FRA
# 108   2001             Alicia Koplowitz   490           Spain         ESP
# 2479  2014                  Wang Muqing  1565           China         CHN
# 1834  2014                  Pavel Tykac  1565  Czech Republic         CZE
# 1371  2014                 Lam Fong Ngo  1565           Macau         MAC
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 1048                1.0  inherited                 inherited    male  56.0
# ...

# %% [markdown]
# ### what are the most common relationships?

# %%
billion.groupby('relationshiptocompany')['name'].count()
# Out:
# relationshiptocompany
# CEO                                                16
# COO                                                 1
# Chairman                                            8
# Chairman and Chief Executive Officer               29
# Chairman, CEO                                       1
# Chairman/founder                                    1
# Chairman/shareholder                                1
# Chief Executive                                     2
# Exectuitve Director                                 1
# Global Head of Real Estate                          1
# Head of Board of Directors                          1
# Honorary President for Life                         1
# Relation                                            6
# Vice Chairman                                       3
# Vice President                                      1
# Vice President of Infrastructure Software           1
# ceo                                                 9
# ...

# %% [markdown]
# ### What are the most common industries for billionaires to come from? What's the total amount of billionaire money from each industry?

# %%
billion.groupby('industry')['name'].count()
# Out:
# industry
# 0                                   16
# Constrution                         97
# Consumer                           471
# Diversified financial              167
# Energy                             132
# Hedge funds                         67
# Media                              219
# Mining and metals                   90
# Money Management                   249
# Non-consumer industrial            107
# Other                               83
# Private equity/leveraged buyout     25
# Real Estate                        280
# Retail, Restaurant                 281
# Technology-Computer                208
# Technology-Medical                 111
# Venture Capital                      8
# banking                              1
# services                             1
# Name: name, dtype: int64

# %%
billion.groupby('industry')['networthusbillion'].sum()
# Out:
# industry
# 0                                    24.7
# Constrution                         236.4
# Consumer                           1756.3
# Diversified financial               702.9
# Energy                              433.3
# Hedge funds                         223.8
# Media                               852.5
# Mining and metals                   282.8
# Money Management                    710.7
# Non-consumer industrial             348.9
# Other                               222.8
# Private equity/leveraged buyout      87.9
# Real Estate                         844.2
# Retail, Restaurant                 1161.3
# Technology-Computer                1015.2
# Technology-Medical                  311.0
# Venture Capital                      14.2
# banking                               1.3
# services                              1.2
# Name: networthusbillion, dtype: float64

# %% [markdown]
# ### How many self made billionaires vs. others?

# %%
billion.groupby('selfmade').count()
# Out:
#            year  name  rank  citizenship  countrycode  networthusbillion  \
# selfmade
# inherited   954   954   954          954          954                954
# self-made  1638  1638  1638         1638         1638               1638
#
#            typeofwealth  gender   age  industry    ...     \
# selfmade                                           ...
# inherited           954     932   875       954    ...
# self-made          1638    1638  1534      1637    ...
#
#            relationshiptocompany  foundingdate  gdpcurrentus  sourceofwealth  \
# selfmade
# inherited                    932           950           446             505
# self-made                   1633          1620           483            1132
#
#            notes  notes2  source  source_2  source_3  source_4
# selfmade
# inherited    928     191     939       681       226        11
# self-made    262       6    1622      1457       549        12
#
# [2 rows x 29 columns]

# %% [markdown]
# ### How old are billionaires? How old are billionaires self made vs. non self made? or different industries?

# %%
billion['age'].describe()
# Out:
# /Users/zhizhou/.virtualenvs/data-analysis/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    2429.000000
# mean       57.403870
# std        21.386215
# min       -42.000000
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max        98.000000
# Name: age, dtype: float64

# %%
billion.groupby('selfmade')['age'].describe()
# Out:
# /Users/zhizhou/.virtualenvs/data-analysis/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# selfmade
# inherited  count     875.000000
#            mean       54.912000
#            std        24.220153
#            min         0.000000
#            25%              NaN
#            50%              NaN
#            75%              NaN
#            max        98.000000
# self-made  count    1534.000000
#            mean       59.474576
#            std        18.513557
#            min       -42.000000
#            25%              NaN
#            50%              NaN
#            75%              NaN
#            max        96.000000
# Name: age, dtype: float64

# %% [markdown]
# ### Who are the youngest billionaires? The oldest? Age distribution - maybe make a graph about it?

# %%
billion.sort_values('age').head(3)
# Out:
#       year             name  rank citizenship countrycode  networthusbillion  \
# 1355  1996   Kunio Busujima   249       Japan         JPN                1.6
# 1297  1996  Kenichi Mabuchi   354       Japan         JPN                1.1
# 1180  1996      John Latsis   120      Greece         GRC                2.6
#
#        selfmade         typeofwealth gender   age   ...     \
# 1355  self-made  founder non-finance   male -42.0   ...
# 1297  self-made  founder non-finance   male  -7.0   ...
# 1180  inherited            inherited   male   0.0   ...
#
#      relationshiptocompany foundingdate  gdpcurrentus  sourceofwealth  \
# 1355               founder       1950.0  4.710000e+12             NaN
# 1297               founder       1946.0  4.710000e+12             NaN
# 1180              relation       1938.0  1.470000e+11             NaN
#
#                       notes                        notes2  \
# 1355                    NaN                           NaN
# ...

# %%
billion.sort_values('age',ascending=False).head(5)
# Out:
#       year                    name  rank    citizenship countrycode  \
# 516   2014  David Rockefeller, Sr.   580  United States         USA
# 1277  2014           Karl Wlaschek   305        Austria         AUT
# 1328  2014          Kirk Kerkorian   328  United States         USA
# 921   2014           Henry Hillman   687  United States         USA
# 666   2014      Erika Pohl-Stroher  1154        Germany         DEU
#
#       networthusbillion   selfmade         typeofwealth  gender   age  \
# 516                 2.9  inherited            inherited    male  98.0
# 1277                4.8  self-made  founder non-finance    male  96.0
# 1328                4.5  self-made    self-made finance    male  96.0
# 921                 2.5  inherited            inherited    male  95.0
# 666                 1.5  inherited            inherited  female  95.0
#
#        ...    relationshiptocompany foundingdate gdpcurrentus  \
# 516    ...                 relation       1870.0          NaN
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
billion['age'].hist()

# %% [markdown]
# ### Maybe just made a graph about how wealthy they are in general?

# %%
billion['networthusbillion'].hist()

# %% [markdown]
# ### Maybe plot their net worth vs age (scatterplot)

# %%
plt.style.use('ggplot')
billion.plot(kind='scatter', x='age', y='networthusbillion',xlim=(-50,100),ylim=(0,80))

# %% [markdown]
# ### Make a bar graph of the top 10 or 20 richest

# %%
billion.sort_values('networthusbillion',ascending=False).head(10).plot(kind='barh',x='name',y='networthusbillion')
# shows with * always....
